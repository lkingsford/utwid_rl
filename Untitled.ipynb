# %%
import mon2y
import pandas as pd

# %%
raw_results = mon2y.explore(
        mon2y.Games.EBR,
        100,
        4,
    )

pd.DataFrame(raw_results)

# raw_results
# Out:
#      turns  rwalk  sum_diff_est_reward  total_bonds_issued end_game_reason  \
# 0       85     84             0.000000                   6      Bankruptcy
# 1       73     72             0.000000                   6      Bankruptcy
# 2      136    135             0.000000                   7      Bankruptcy
# 3       86     85             0.000000                   6           Bonds
# 4       35     34             0.000000                   1       Stalemate
# ..     ...    ...                  ...                 ...             ...
# 99      82     80             0.845810                   6      Bankruptcy
# 100     83     79             0.803852                   6      Bankruptcy
# 101     83     80             0.816977                   3       Dividends
# 102    101     98             0.816977                   7      Bankruptcy
# 103    109    106            -0.038172                   7      Bankruptcy
#
#      remaining_resource_cubes  ebrc_connected_to_devonport  \
# ...
